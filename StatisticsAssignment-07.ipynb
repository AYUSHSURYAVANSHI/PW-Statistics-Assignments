# %%
# Q1. Calculate the 95% confidence interval for a sample of data with a mean of 50 and a standard deviation 
# of 5 using Python. Interpret the results.
# Answer :-
import scipy.stats as stats

# Sample statistics
sample_mean = 50
sample_std_dev = 5

# Sample size (you need to specify the sample size for the confidence interval calculation)
sample_size = 100  # Replace this with your actual sample size

# Confidence level
confidence_level = 0.95

# Calculate the margin of error
margin_of_error = stats.norm.ppf((1 + confidence_level) / 2) * (sample_std_dev / (sample_size**0.5))

# Calculate the confidence interval
lower_limit = sample_mean - margin_of_error
upper_limit = sample_mean + margin_of_error

print(f"95% Confidence Interval: ({lower_limit:.2f}, {upper_limit:.2f})")
# Out:
#   Cell In[1], line 1
#     Q1. Calculate the 95% confidence interval for a sample of data with a mean of 50 and a standard deviation
#                   ^
# SyntaxError: invalid syntax

# %%
# Q2. Conduct a chi-square goodness of fit test to determine if the distribution of colors of M&Ms in a bag 
# matches the expected distribution of 20% blue, 20% orange, 20% green, 10% yellow, 10% red, and 20% 
# brown. Use Python to perform the test with a significance level of 0.05.
# Answer :-
import scipy.stats as stats

# Observed frequencies (counts of each color in the bag)
observed_counts = [25, 18, 22, 13, 12, 20]  # These numbers are hypothetical and should be replaced with your actual data

# Expected frequencies (expected proportions based on the expected distribution)
expected_counts = [0.20, 0.20, 0.20, 0.10, 0.10, 0.20]  # Expected proportions

# Total number of M&Ms in the bag
total_count = sum(observed_counts)

# Calculate expected counts based on the total count
expected_counts = [count * total_count for count in expected_counts]

# Perform the chi-square goodness of fit test
chi2, p_value = stats.chisquare(observed_counts, f_exp=expected_counts)

# Define the significance level
alpha = 0.05

# Compare the p-value to the significance level
if p_value < alpha:
    print("The distribution of colors in the bag does not match the expected distribution (reject the null hypothesis).")
else:
    print("The distribution of colors in the bag matches the expected distribution (fail to reject the null hypothesis).")

print(f"Chi-square statistic: {chi2:.2f}")
print(f"P-value: {p_value:.4f}")

# %%
#  Q3. Use Python to calculate the chi-square statistic and p-value for a contingency table with the following 
# data:
#  Interpret the results of the test.
# Answer :-
import scipy.stats as stats

# Create the contingency table
observed_data = [[10, 15, 25],
                 [20, 30, 40]]

# Perform the chi-square test for independence
chi2, p_value, _, _ = stats.chi2_contingency(observed_data)

# Define the significance level
alpha = 0.05

print(f"Chi-square statistic: {chi2:.2f}")
print(f"P-value: {p_value:.4f}")

if p_value < alpha:
    print("The variables are dependent (reject the null hypothesis).")
else:
    print("The variables are independent (fail to reject the null hypothesis).")

# %%
#  Q4. A study of the prevalence of smoking in a population of 500 individuals found that 60 individuals 
# smoked. Use Python to calculate the 95% confidence interval for the true proportion of individuals in the 
# population who smoke.
# Answer :-
import scipy.stats as stats

# Sample size
total_population = 500
sample_size = 60  # Number of individuals who smoke

# Proportion of individuals who smoke in the sample
sample_proportion = sample_size / total_population

# Confidence level
confidence_level = 0.95

# Calculate the margin of error
margin_of_error = stats.norm.ppf((1 + confidence_level) / 2) * ((sample_proportion * (1 - sample_proportion)) / total_population)**0.5

# Calculate the confidence interval
lower_limit = sample_proportion - margin_of_error
upper_limit = sample_proportion + margin_of_error

print(f"95% Confidence Interval for the proportion of individuals who smoke: ({lower_limit:.4f}, {upper_limit:.4f})")

# %%
#  Q5. Calculate the 90% confidence interval for
#  a sample of data with a mean of 75 and a standard deviation 
# of 12 using Python. Interpret the results.
# Answer :-
import scipy.stats as stats

# Sample statistics
sample_mean = 75
sample_std_dev = 12

# Sample size (you need to specify the sample size for the confidence interval calculation)
sample_size = 100  # Replace this with your actual sample size

# Confidence level
confidence_level = 0.90

# Calculate the margin of error
margin_of_error = stats.norm.ppf((1 + confidence_level) / 2) * (sample_std_dev / (sample_size**0.5))

# Calculate the confidence interval
lower_limit = sample_mean - margin_of_error
upper_limit = sample_mean + margin_of_error

print(f"90% Confidence Interval: ({lower_limit:.2f}, {upper_limit:.2f})")

# %%
# Q6. Use Python to plot the chi-square distribution with 10 degrees of freedom. Label the axes and shade the 
# area corresponding to a chi-square statistic of 15.
# Answer :-
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# Degrees of freedom
df = 10

# Create an array of x values for the chi-square distribution
x = np.linspace(0, 30, 1000)

# Calculate the probability density function (PDF) for the chi-square distribution
pdf = stats.chi2.pdf(x, df)

# Create a plot
plt.plot(x, pdf, label=f'Chi-Square ({df} degrees of freedom)')

# Shade the area corresponding to a chi-square statistic of 15
x_shade = np.linspace(0, 15, 1000)
plt.fill_between(x_shade, stats.chi2.pdf(x_shade, df), color='gray', alpha=0.5, label='Chi-Square Statistic = 15')

# Label the axes and add a legend
plt.xlabel('Chi-Square Value')
plt.ylabel('Probability Density')
plt.legend()

# Show the plot
plt.title('Chi-Square Distribution with Shaded Area (Chi-Square Statistic = 15)')
plt.grid()
plt.show()

# %%
# Q7. A random sample of 1000 people was asked if they preferred Coke or Pepsi. Of the sample, 520 
# preferred Coke. Calculate a 99% confidence interval for the true proportion of people in the population who 
# prefer Coke.
# Answer :-
import scipy.stats as stats

# Sample statistics
sample_size = 1000  # Sample size
preferred_coke = 520  # Number of people who preferred Coke

# Sample proportion of people who preferred Coke
sample_proportion = preferred_coke / sample_size

# Confidence level
confidence_level = 0.99

# Calculate the margin of error
margin_of_error = stats.norm.ppf((1 + confidence_level) / 2) * (sample_proportion * (1 - sample_proportion) / sample_size)**0.5

# Calculate the confidence interval
lower_limit = sample_proportion - margin_of_error
upper_limit = sample_proportion + margin_of_error

print(f"99% Confidence Interval for the proportion of people who prefer Coke: ({lower_limit:.4f}, {upper_limit:.4f})")

# %%
# Q8. A researcher hypothesizes that a coin is biased towards tails. They flip the coin 100 times and observe 
# 45 tails. Conduct a chi-square goodness of fit test to determine if the observed frequencies match the 
# expected frequencies of a fair coin. Use a significance level of 0.05.
# Answer :-
import scipy.stats as stats

# Observed frequencies
observed_tails = 45
observed_heads = 100 - observed_tails

# Expected frequencies for a fair coin
expected_tails = 50  # 50% tails expected
expected_heads = 50  # 50% heads expected

# Create observed and expected frequency arrays
observed_freq = [observed_tails, observed_heads]
expected_freq = [expected_tails, expected_heads]

# Perform the chi-square goodness of fit test
chi2, p_value = stats.chisquare(f_obs=observed_freq, f_exp=expected_freq)

# Define the significance level
alpha = 0.05

print(f"Chi-square statistic: {chi2:.2f}")
print(f"P-value: {p_value:.4f}")

if p_value < alpha:
    print("The coin may be biased towards tails (reject the null hypothesis).")
else:
    print("The coin is not biased towards tails (fail to reject the null hypothesis).")
# Out:
#   Cell In[2], line 1
#     Q8. A researcher hypothesizes that a coin is biased towards tails. They flip the coin 100 times and observe
#           ^
# SyntaxError: invalid syntax

# %%
#  Q9. A study was conducted to determine if there is an association between smoking status (smoker or 
# non-smoker) and lung cancer diagnosis (yes or no). The results are shown in the contingency table below. 
# Conduct a chi-square test for independence to determine if there is a significant association between 
# smoking status and lung cancer diagnosis. Use a significance level of 0.05.
# Answer :- 
import scipy.stats as stats

# Create the contingency table
observed_data = [[120, 30],
                 [40, 10]]

# Perform the chi-square test for independence
chi2, p_value, _, _ = stats.chi2_contingency(observed_data)

# Define the significance level
alpha = 0.05

print(f"Chi-square statistic: {chi2:.2f}")
print(f"P-value: {p_value:.4f}")

if p_value < alpha:
    print("There is a significant association between smoking status and lung cancer diagnosis (reject the null hypothesis).")
else:
    print("There is no significant association between smoking status and lung cancer diagnosis (fail to reject the null hypothesis).")

# %%
#  Q10. A study was conducted to determine if the proportion of people who prefer milk chocolate, dark 
# chocolate, or white chocolate is different in the U.S. versus the U.K. A random sample of 500 people from 
# the U.S. and a random sample of 500 people from the U.K. were surveyed. The results are shown in the 
# contingency table below. Conduct a chi-square test for independence to determine if there is a significant 
# association between chocolate preference and country of origin.
#  Use a significance level of 0.01.
# Answer :-
import scipy.stats as stats

# Create the contingency table
observed_data = [[180, 150, 60],  # U.S. sample: Milk, Dark, White chocolate preference
                 [200, 100, 200]]  # U.K. sample: Milk, Dark, White chocolate preference

# Perform the chi-square test for independence
chi2, p_value, _, _ = stats.chi2_contingency(observed_data)

# Define the significance level
alpha = 0.01

print(f"Chi-square statistic: {chi2:.2f}")
print(f"P-value: {p_value:.4f}")

if p_value < alpha:
    print("There is a significant association between chocolate preference and country of origin (reject the null hypothesis).")
else:
    print("There is no significant association between chocolate preference and country of origin (fail to reject the null hypothesis).")

# %%
# Q11. A random sample of 30 people was selected from a population with an unknown mean and standard 
# deviation. The sample mean was found to be 72 and the sample standard deviation was found to be 10. 
# Conduct a hypothesis test to determine if the population mean is significantly different from 70. Use a 
# significance level of 0.05.
# Answer :-
import scipy.stats as stats

# Sample statistics
sample_mean = 72
sample_std_dev = 10

# Population mean under the null hypothesis
population_mean_null = 70

# Sample size
sample_size = 30

# Significance level
alpha = 0.05

# Calculate the t-statistic
t_statistic = (sample_mean - population_mean_null) / (sample_std_dev / (sample_size**0.5))

# Calculate the degrees of freedom
degrees_of_freedom = sample_size - 1

# Calculate the p-value
p_value = 2 * (1 - stats.t.cdf(abs(t_statistic), df=degrees_of_freedom))

print(f"t-statistic: {t_statistic:.4f}")
print(f"P-value: {p_value:.4f}")

if p_value < alpha:
    print("The population mean is significantly different from 70 (reject the null hypothesis).")
else:
    print("There is no significant difference between the population mean and 70 (fail to reject the null hypothesis).")
